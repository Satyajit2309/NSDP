# %%
import pandas as pd 
import os

# %%
df = pd.read_csv("./dataset.csv")

df = df[:-3]
df
# Out:
#     Sr.No.                                     Industry Group   2011-12  \
# 0      1.0  Agriculture, Forestry and logging, Fishing and...  118950.0
# 1      1.1                         Of which Crops & Livestock   93776.0
# 2      2.0  Manufacturing, Electricity, Gas, Water Supply ...  168931.0
# 3      2.1                             Of which Manufacturing  111849.0
# 4      3.0  Trade, Repair Services And Hotels & Restaurant...   90417.0
# 5      4.0  Financial Services, Real estate, Ownership of ...   57753.0
# 6      5.0           Public Administration and Other Services   33074.0
# 7      6.0                       Sub-total : Tertiary (3+4+5)  181244.0
# 8      7.0  Total Net State Value Added at Basic prices (1...  469125.0
# 9      8.0                                  Taxes on Products   77004.0
# 10     9.0                         Less Subsidies on Products   13319.0
# 11    10.0  Total Net State Domestic Product at Market pri...  532810.0
#
# ...

# %%
industries = df['Industry Group'].unique()
industries
# Out:
# array(['Agriculture, Forestry and logging, Fishing and aquaculture, Mining & Quarrying',
#        'Of which Crops & Livestock',
#        'Manufacturing, Electricity, Gas, Water Supply & Other utility services and Construction',
#        'Of which Manufacturing',
#        'Trade, Repair Services And Hotels & Restaurants, Transport, Storage, Communication & Services related to broadcasting',
#        'Financial Services, Real estate, Ownership of dwelling & Professional services',
#        'Public Administration and Other Services',
#        'Sub-total : Tertiary (3+4+5)',
#        'Total Net State Value Added at Basic prices (1+2+6)',
#        'Taxes on Products', 'Less Subsidies on Products',
#        'Total Net State Domestic Product at Market prices (7+8-9)'],
#       dtype=object)
